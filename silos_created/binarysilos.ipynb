# %%
import pandas as pd 
import os 
import numpy as np

# %%
RANDOM_SEED = 42

# %%
### Combining all the datasets 
silo_path = '../silos_datasets/'
datasets = []

for filename in os.listdir(silo_path):
    if filename.endswith('.csv'):
        filepath = os.path.join(silo_path, filename) ### Creating a file path for each directory
        data = pd.read_csv(filepath)
        datasets.append(data)
    
combined_datasets = pd.concat(datasets, ignore_index=True)
combined_datasets.head(5)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              60453              94                   1
# 1              53904              63                   1
# 2                 80        83165164                   7
# 3                 80        85013328                   6
# 4                 80        83303368                   8
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            0
# 1                        1                            0
# 2                        6                          354
# 3                        6                          361
# 4                        5                          337
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       0
# 1                             0                       0
# 2                         11595                     348
# 3                         11595                     361
# 4                         11595                     337
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                 0.000000                0.000000
# 1                       0                 0.000000                0.000000
# 2                       0                50.571429              131.172732
# 3                       0                60.166667              147.377633
# 4                       0                42.125000              119.147493
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     32          0.0          0.0            0
# 1  ...                     32          0.0          0.0            0
# 2  ...                     20         51.0          0.0           51
# 3  ...                     32       1014.0          0.0         1014
# 4  ...                     32       1011.0          0.0         1011
#
#     Active Min   Idle Mean   Idle Std   Idle Max   Idle Min     Label
# 0            0         0.0        0.0          0          0    BENIGN
# 1            0         0.0        0.0          0          0    BENIGN
# 2           51  83100000.0        0.0   83100000   83100000  DoS Hulk
# 3         1014  84900000.0        0.0   84900000   84900000  DoS Hulk
# 4         1011  83200000.0        0.0   83200000   83200000  DoS Hulk
#
# [5 rows x 79 columns]

# %%
print(combined_datasets[' Label'].value_counts())
attack_data = combined_datasets[combined_datasets[' Label'] != 'BENIGN']
non_attack_data = combined_datasets[combined_datasets[' Label'] == 'BENIGN']
print("----------")
print(f" Total attack samples are {attack_data.shape[0]}")
print(f"Total non-attack samples are {non_attack_data.shape[0]}")
# Out:
#  Label
# BENIGN                    556488
# DoS Hulk                  230124
# PortScan                  158804
# DDoS                      128025
# DoS GoldenEye              10293
# FTP-Patator                 7935
# SSH-Patator                 5897
# DoS slowloris               5796
# DoS Slowhttptest            5499
# Bot                         1956
# Web Attack Brute Force      1507
# Web Attack XSS               652
# Name: count, dtype: int64
# ----------
#  Total attack samples are 556488
# Total non-attack samples are 556488

# %%
### Binary classed for each of the silos 
pd1 = pd.read_csv('../silos_datasets/siloOne.csv')
pd1
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 0                   60453              94                   1
# 1                   53904              63                   1
# 2                      80        83165164                   7
# 3                      80        85013328                   6
# 4                      80        83303368                   8
# ...                   ...             ...                 ...
# 503419                 80        63095538                   7
# 503420                 80             218                   2
# 503421                443         2087714                  11
# 503422                 80        60492231                  10
# 503423                 53           31971                   2
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                             1                            0
# 1                             1                            0
# 2                             6                          354
# 3                             6                          361
# 4                             5                          337
# ...                         ...                          ...
# 503419                        0                            0
# 503420                        0                            0
# 503421                        6                         1045
# 503422                       10                          430
# 503423                        2                           66
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                                  0                       0
# 1                                  0                       0
# 2                              11595                     348
# 3                              11595                     361
# 4                              11595                     337
# ...                              ...                     ...
# 503419                             0                       0
# 503420                             0                       0
# 503421                          1375                     432
# 503422                           168                     382
# 503423                           190                      33
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                            0                 0.000000
# 1                            0                 0.000000
# 2                            0                50.571429
# 3                            0                60.166667
# 4                            0                42.125000
# ...                        ...                      ...
# 503419                       0                 0.000000
# 503420                       0                 0.000000
# 503421                       0                95.000000
# 503422                       0                43.000000
# 503423                      33                33.000000
#
#          Fwd Packet Length Std  ...   min_seg_size_forward   Active Mean  \
# 0                     0.000000  ...                     32  0.000000e+00
# 1                     0.000000  ...                     32  0.000000e+00
# 2                   131.172732  ...                     20  5.100000e+01
# 3                   147.377633  ...                     32  1.014000e+03
# 4                   119.147493  ...                     32  1.011000e+03
# ...                        ...  ...                    ...           ...
# 503419                0.000000  ...                     40  7.008270e+06
# 503420                0.000000  ...                     32  0.000000e+00
# 503421              158.564813  ...                     32  0.000000e+00
# 503422              119.127383  ...                     20  6.517517e+04
# 503423                0.000000  ...                     20  0.000000e+00
#
#          Active Std   Active Max   Active Min     Idle Mean      Idle Std  \
# 0            0.0000            0            0  0.000000e+00  0.000000e+00
# 1            0.0000            0            0  0.000000e+00  0.000000e+00
# 2            0.0000           51           51  8.310000e+07  0.000000e+00
# 3            0.0000         1014         1014  8.490000e+07  0.000000e+00
# 4            0.0000         1011         1011  8.320000e+07  0.000000e+00
# ...             ...          ...          ...           ...           ...
# 503419       0.0000      7008270      7008270  1.870000e+07  1.220000e+07
# 503420       0.0000            0            0  0.000000e+00  0.000000e+00
# 503421       0.0000            0            0  0.000000e+00  0.000000e+00
# 503422   35992.9829       138645        50332  9.996616e+06  1.013091e+04
# 503423       0.0000            0            0  0.000000e+00  0.000000e+00
#
#          Idle Max   Idle Min             Label
# 0               0          0            BENIGN
# 1               0          0            BENIGN
# 2        83100000   83100000          DoS Hulk
# 3        84900000   84900000          DoS Hulk
# 4        83200000   83200000          DoS Hulk
# ...           ...        ...               ...
# 503419   32000000    8023641  DoS Slowhttptest
# 503420          0          0          DoS Hulk
# 503421          0          0            BENIGN
# 503422   10000000    9976221            BENIGN
# 503423          0          0            BENIGN
#
# [503424 rows x 79 columns]

# %%
print(pd1[' Label'].value_counts())
# Out:
#  Label
# BENIGN              251712
# DoS Hulk            230124
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Name: count, dtype: int64

# %%
pd2 = pd.read_csv('../silos_datasets/siloTwo.csv')
pd2.head(5)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              52742           26932                   2
# 1              39839              52                   1
# 2               5950              48                   1
# 3                 53             411                   2
# 4                705              11                   1
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                           44
# 1                        1                            0
# 2                        1                            0
# 3                        2                           94
# 4                        1                            2
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                      38
# 1                             0                       0
# 2                             6                       0
# 3                           542                      47
# 4                             6                       2
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       6                     22.0               22.627417
# 1                       0                      0.0                0.000000
# 2                       0                      0.0                0.000000
# 3                      47                     47.0                0.000000
# 4                       2                      2.0                0.000000
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     20          0.0          0.0            0
# 1  ...                     32          0.0          0.0            0
# 2  ...                     40          0.0          0.0            0
# 3  ...                     20          0.0          0.0            0
# 4  ...                     24          0.0          0.0            0
#
#     Active Min  Idle Mean   Idle Std   Idle Max   Idle Min     Label
# 0            0        0.0        0.0          0          0    BENIGN
# 1            0        0.0        0.0          0          0    BENIGN
# 2            0        0.0        0.0          0          0  PortScan
# 3            0        0.0        0.0          0          0    BENIGN
# 4            0        0.0        0.0          0          0  PortScan
#
# [5 rows x 79 columns]

# %%
print(pd2[' Label'].value_counts())
# Out:
#  Label
# BENIGN      288785
# PortScan    158804
# DDoS        128025
# Bot           1956
# Name: count, dtype: int64

# %%
pd3 = pd.read_csv('../silos_datasets/siloThree.csv')
pd3.head(5)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 21             221                   2
# 1                 53          612792                   1
# 2                443       110219468                  24
# 3                 53           37750                   2
# 4                 88             755                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                           14
# 1                        1                           48
# 2                       27                        15380
# 3                        2                           54
# 4                        2                          504
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                      14
# 1                           148                      48
# 2                          2414                    3050
# 3                            86                      27
# 4                          2884                     252
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                 7.000000                9.899495
# 1                      48                48.000000                0.000000
# 2                       0               640.833333             1051.835070
# 3                      27                27.000000                0.000000
# 4                     252               252.000000                0.000000
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     32          0.0        0.000            0
# 1  ...                     20          0.0        0.000            0
# 2  ...                     20    1057008.5  2151750.002      5228249
# 3  ...                     32          0.0        0.000            0
# 4  ...                     20          0.0        0.000            0
#
#     Active Min  Idle Mean     Idle Std   Idle Max   Idle Min        Label
# 0            0        0.0      0.00000          0          0  FTP-Patator
# 1            0        0.0      0.00000          0          0       BENIGN
# 2        23580  9962586.9  48857.08944   10000000    9850722       BENIGN
# 3            0        0.0      0.00000          0          0       BENIGN
# 4            0        0.0      0.00000          0          0       BENIGN
#
# [5 rows x 79 columns]

# %%
print(pd3[' Label'].value_counts())
# Out:
#  Label
# BENIGN         13832
# FTP-Patator     7935
# SSH-Patator     5897
# Name: count, dtype: int64

# %%
pd4 = pd.read_csv('../silos_datasets/siloFour.csv')
pd4.head(5)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80       117286545                  21
# 1                 80         5243646                   3
# 2                 53           31216                   1
# 3                 53           31368                   2
# 4                443        61143903                  15
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       18                          710
# 1                        1                            0
# 2                        1                           64
# 3                        2                           72
# 4                       14                          982
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          4414                     357
# 1                             0                       0
# 2                           130                      64
# 3                           236                      36
# 4                          7291                     698
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                33.809524              106.783247
# 1                       0                 0.000000                0.000000
# 2                      64                64.000000                0.000000
# 3                      36                36.000000                0.000000
# 4                       0                65.466667              184.588681
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     32  190673.1818  529211.8730      1786307
# 1  ...                     32       0.0000       0.0000            0
# 2  ...                     20       0.0000       0.0000            0
# 3  ...                     20       0.0000       0.0000            0
# 4  ...                     32  260864.8333  175721.8448       619555
#
#     Active Min     Idle Mean      Idle Std   Idle Max   Idle Min  \
# 0        31007  1.000000e+07    4365.02479   10000000   10000000
# 1            0  0.000000e+00       0.00000          0          0
# 2            0  0.000000e+00       0.00000          0          0
# 3            0  0.000000e+00       0.00000          0          0
# 4       188857  9.929724e+06  316284.11450   10200000    9298227
#
#             Label
# 0          BENIGN
# 1  Web Attack XSS
# 2          BENIGN
# 3          BENIGN
# 4          BENIGN
#
# [5 rows x 79 columns]

# %%
print(pd4[' Label'].value_counts())
# Out:
#  Label
# BENIGN                    2159
# Web Attack Brute Force    1507
# Web Attack XSS             652
# Name: count, dtype: int64

# %% [markdown]
# ### Silo 4 contributes fewer samples due to the natural scarcity of web attack traffic, reflecting real world heterogenity in federated environments.

# %% [markdown]
# ### Converting all the silos to binary

# %%
def binary_silos_converter(df):
    df = df.copy()
    df['Label_Binary'] = df[' Label'].apply(lambda x: 0 if x == 'BENIGN' else 1)
    df = df.drop(columns = ' Label')
    return df

# %%
pd1_binary = binary_silos_converter(pd1)
print(pd1_binary['Label_Binary'].value_counts())
pd1_binary.to_csv('../silos_datasets/SiloBinaryOne.csv')
# Out:
# Label_Binary
# 0    251712
# 1    251712
# Name: count, dtype: int64

# %%
### Creating the pd2_binary 
pd2_binary = binary_silos_converter(pd2)
print(pd2_binary['Label_Binary'].value_counts())
pd2_binary.to_csv('../silos_datasets/SiloBinaryTwo.csv')
# Out:
# Label_Binary
# 0    288785
# 1    288785
# Name: count, dtype: int64

# %%
pd3_binary = binary_silos_converter(pd3)
print(pd3_binary['Label_Binary'].value_counts())
pd3_binary.to_csv('../silos_datasets/SiloBinaryThree.csv')
# Out:
# Label_Binary
# 1    13832
# 0    13832
# Name: count, dtype: int64

# %%
pd4_binary = binary_silos_converter(pd4)
print(pd4_binary['Label_Binary'].value_counts())
pd4_binary.to_csv('../silos_datasets/SiloBinaryFour.csv')
# Out:
# Label_Binary
# 0    2159
# 1    2159
# Name: count, dtype: int64

# %%
## Creating the combined dataset
binary_combined_dataset = pd.concat()
