# %%
import pandas as pd 
import os 
import numpy as np

# %%
daily_dataset_directory = '../datasets/'
dataframes = []
for filename in os.listdir(daily_dataset_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(daily_dataset_directory, filename)
        data = pd.read_csv(file_path)
        print(data)
        combined_data = combined_data.append(data, ignore_index = True)
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 0                      22             166                   1
# 1                   60148              83                   1
# 2                     123           99947                   1
# 3                     123           37017                   1
# 4                       0       111161336                 147
# ...                   ...             ...                 ...
# 288597                 80          590930                   2
# 288598                 80         1187988                   2
# 288599                 80              10                   1
# 288600                138              19                  10
# 288601                 80         4751966                   2
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                             1                            0
# 1                             2                            0
# 2                             1                           48
# 3                             1                           48
# 4                             0                            0
# ...                         ...                          ...
# 288597                        0                            0
# 288598                        0                            0
# 288599                        9                            6
# 288600                        0                         2370
# 288601                        0                            0
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                                  0                       0
# 1                                  0                       0
# 2                                 48                      48
# 3                                 48                      48
# 4                                  0                       0
# ...                              ...                     ...
# 288597                             0                       0
# 288598                             0                       0
# 288599                            54                       6
# 288600                             0                     237
# 288601                             0                       0
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                            0                      0.0
# 1                            0                      0.0
# 2                           48                     48.0
# 3                           48                     48.0
# 4                            0                      0.0
# ...                        ...                      ...
# 288597                       0                      0.0
# 288598                       0                      0.0
# 288599                       6                      6.0
# 288600                     237                    237.0
# 288601                       0                      0.0
#
#          Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 0                          0.0  ...                     32        0.000
# 1                          0.0  ...                     32        0.000
# 2                          0.0  ...                     40        0.000
# 3                          0.0  ...                     32        0.000
# 4                          0.0  ...                      0  1753752.625
# ...                        ...  ...                    ...          ...
# 288597                     0.0  ...                     32        0.000
# 288598                     0.0  ...                     32        0.000
# 288599                     0.0  ...                     20        0.000
# 288600                     0.0  ...                     20        0.000
# 288601                     0.0  ...                     32        0.000
#
#          Active Std   Active Max   Active Min  Idle Mean     Idle Std  \
# 0             0.000            0            0        0.0        0.000
# 1             0.000            0            0        0.0        0.000
# 2             0.000            0            0        0.0        0.000
# 3             0.000            0            0        0.0        0.000
# 4       2123197.578      4822992           95  9463032.7  2657727.996
# ...             ...          ...          ...        ...          ...
# 288597        0.000            0            0        0.0        0.000
# 288598        0.000            0            0        0.0        0.000
# 288599        0.000            0            0        0.0        0.000
# 288600        0.000            0            0        0.0        0.000
# 288601        0.000            0            0        0.0        0.000
#
#          Idle Max   Idle Min   Label
# 0               0          0  BENIGN
# 1               0          0  BENIGN
# 2               0          0  BENIGN
# 3               0          0  BENIGN
# 4        13600000    5700287  BENIGN
# ...           ...        ...     ...
# 288597          0          0  BENIGN
# 288598          0          0  BENIGN
# 288599          0          0  BENIGN
# 288600          0          0  BENIGN
# 288601          0          0  BENIGN
#
# [288602 rows x 79 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bt/9_3kc80d4jq8sv8fv_c7d_fr0000gn/T/ipykernel_18590/4063540482.py in ?()
#       4     if filename.endswith('.csv'):
#       5         file_path = os.path.join(daily_dataset_directory, filename)
#       6         data = pd.read_csv(file_path)
#       7         print(data)
# ----> 8         combined_data = combined_data.append(data, ignore_index = True)
#       9
#
# /opt/anaconda3/envs/miniproject/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
